# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets
from sklearn import decomposition
import matplotlib.pyplot as plt
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
import numpy as np

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
pca = decomposition.PCA(n_components=3)
X = pca.fit_transform(X)
X
# Out:
# array([[ 28.47993992,  -3.43359359,   1.03184821],
#        [-22.59666568,  17.80122274,   6.11085604],
#        [ -8.83188035,  11.46680509,   2.01624677],
#        ...,
#        [-22.05029473, -16.58404599,  -5.73396933],
#        [-16.44102253, -17.48311967,  -3.95362912],
#        [ 28.5723742 ,   1.03814293,   5.45381176]])

# %%
fig = plt.figure(1,  figsize=(10,8))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()

for name, label in [("One", 0), ("Two", 1), ("Three", 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean(),
              X[y == label, 2].mean(),
              name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w')    
    )

colors = np.choose(y, [10, 20, 100])
ax.scatter(X[:,0], X[:, 1], X[:, 2], c=colors, cmap=plt.cm.nipy_spectral, edgecolors="k")

# ax.w_xaxis.set_ticklabels([])
# ax.w_yaxis.set_ticklabels([])
# ax.w_zaxis.set_ticklabels([])
